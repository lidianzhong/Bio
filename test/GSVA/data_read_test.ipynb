# %% [markdown]
# ### gene expression data

# %%
import pandas as pd

# Read the file
expression_df_raw = pd.read_csv('../../data/GDSC/Cell_line_RMA_proc_basalExp.txt', sep='\t')
expression_df_raw.head()
# Out:
#   GENE_SYMBOLS                                         GENE_title  \
# 0       TSPAN6       tetraspanin 6 [Source:HGNC Symbol;Acc:11858]
# 1         TNMD         tenomodulin [Source:HGNC Symbol;Acc:17757]
# 2         DPM1  dolichyl-phosphate mannosyltransferase polypep...
# 3        SCYL3  SCY1-like 3 (S. cerevisiae) [Source:HGNC Symbo...
# 4     C1orf112  chromosome 1 open reading frame 112 [Source:HG...
#
#    DATA.906826  DATA.687983  DATA.910927  DATA.1240138  DATA.1240139  \
# 0     7.632023     7.548671     8.712338      7.797142      7.729268
# 1     2.964585     2.777716     2.643508      2.817923      2.957739
# 2    10.379553    11.807341     9.880733      9.883471     10.418840
# 3     3.614794     4.066887     3.956230      4.063701      4.341500
# 4     3.380681     3.732485     3.236620      3.558414      3.840373
#
#    DATA.906792  DATA.910688  DATA.1240135  ...  DATA.753584  DATA.907044  \
# 0     7.074533     3.285198      6.961606  ...     7.105637     3.236503
# ...

# %%
expression_df = expression_df_raw.drop(expression_df_raw.columns[1], axis=1)
expression_df.set_index(expression_df.columns[0], inplace=True)
expression_df = expression_df[expression_df.index.notnull()]
expression_df.head()
# Out:
#               DATA.906826  DATA.687983  DATA.910927  DATA.1240138  \
# GENE_SYMBOLS
# TSPAN6           7.632023     7.548671     8.712338      7.797142
# TNMD             2.964585     2.777716     2.643508      2.817923
# DPM1            10.379553    11.807341     9.880733      9.883471
# SCYL3            3.614794     4.066887     3.956230      4.063701
# C1orf112         3.380681     3.732485     3.236620      3.558414
#
#               DATA.1240139  DATA.906792  DATA.910688  DATA.1240135  \
# GENE_SYMBOLS
# TSPAN6            7.729268     7.074533     3.285198      6.961606
# TNMD              2.957739     2.889677     2.828203      2.874751
# DPM1             10.418840     9.773987    10.264385     10.205931
# SCYL3             4.341500     4.270903     5.968168      3.715033
# C1orf112          3.840373     3.815055     3.011867      3.268449
#
#               DATA.1290812  DATA.907045  ...  DATA.753584  DATA.907044  \
# GENE_SYMBOLS                             ...
# ...

# %%
expression_df.head(5000).to_csv('expression_df.csv', index=True)

# %% [markdown]
# ### Read pathway data

# %%
import pandas as pd

# Read pathway file
pathway_df = pd.read_csv('/home/ldz/Bio/GSVA/pathway.csv')
pathway_df.head()
# Out:
#                      Unnamed: 0  DATA.906826  DATA.687983  DATA.910927  \
# 0  SA_B_CELL_RECEPTOR_COMPLEXES    -0.331822    -0.200036     0.679713
# 1            SA_CASPASE_CASCADE    -0.030548    -0.700364    -0.154559
# 2              SA_FAS_SIGNALING    -0.209718    -0.847678    -0.540726
# 3            SA_G1_AND_S_PHASES     0.460524     0.338883     0.628796
# 4            SA_G2_AND_M_PHASES     0.701540    -0.101020     0.110222
#
#    DATA.1240138  DATA.1240139  DATA.906792  DATA.910688  DATA.1240135  \
# 0     -0.054999     -0.422538    -0.030690     0.419800      0.039957
# 1      0.304934      0.374745    -0.411184     0.561591      0.361478
# 2      0.656111     -0.267518    -0.604992     0.754130      0.438853
# 3     -0.405005     -0.587932    -0.253651    -0.724804      0.451941
# 4     -0.067814      0.409482    -0.061412    -0.963993     -0.445489
#
#    DATA.1290812  ...  DATA.753584  DATA.907044  DATA.998184  DATA.908145  \
# ...
